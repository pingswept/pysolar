# %%
import rest
rest.get_broadband_direct_normal_irradiance(45.0)
# Out:
# high-frequency
# 0.10658232436
# 0.836702348686
# -260.173914274
# -12.8235481008
# 0.880961871382
# 0.0
# low-frequency
# 0.0357065199122
# -4.43131175029
# 1.0
# 1.0
# 0.319475643881
# 0.0
# 0.0

# %%
mRprime = linspace(0, 100, 1000)
high = map(lambda mRprime: rest.get_rayleigh_transmittance('high-frequency', mRprime), mRprime)
low = map(lambda mRprime: rest.get_rayleigh_transmittance('low-frequency', mRprime), mRprime)
plot(mRprime, high)
show()
plot(mRprime, low)
show()
